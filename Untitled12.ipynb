# %% [markdown]
# <a href="https://colab.research.google.com/github/pradosh2005/DeepLearing01/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as  yf

# %%
data  =  yf.download('MSFT' ,  period='5y')
# Out:
# /tmp/ipython-input-2120185165.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data  =  yf.download('MSFT' ,  period='5y')
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            MSFT        MSFT        MSFT        MSFT      MSFT
# Date
# 2020-10-15  210.615601  211.286775  207.115879  208.161010  22733100
# 2020-10-16  210.615601  213.137302  210.289603  211.085416  26057900
# 2020-10-19  205.399536  213.146846  204.920124  211.344249  27625800
# 2020-10-20  205.811859  208.419865  204.316094  206.914517  22753500
# 2020-10-21  205.955688  207.988394  204.344854  204.344854  22724900
# ...                ...         ...         ...         ...       ...
# 2025-10-08  524.849976  526.950012  523.090027  523.280029  13363400
# 2025-10-09  522.400024  524.330017  517.400024  522.340027  18343600
# 2025-10-10  510.959991  523.580017  509.630005  519.640015  24133800
# 2025-10-13  514.049988  516.409973  511.679993  516.409973  14284200
# 2025-10-14  513.570007  515.280029  506.000000  510.230011  14669900
#
# [1255 rows x 5 columns]

# %%
data.columns
# Out:
# MultiIndex([( 'Close', 'MSFT'),
#             (  'High', 'MSFT'),
#             (   'Low', 'MSFT'),
#             (  'Open', 'MSFT'),
#             ('Volume', 'MSFT')],
#            names=['Price', 'Ticker'])

# %%
data.rename(columns =  {'( 'Close', 'MSFT')' :  'close'} ,  inplace  = True)
# Out:
#   File "/tmp/ipython-input-956949121.py", line 1
#     data.rename(columns =  {'( 'Close', 'MSFT')' :  'close'} ,  inplace  = True)
#                             ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
data.columns    = ['close' ,  'high' ,  'low' ,  'open' ,  'volumn']

# %%
data
# Out:
#                  close        high         low        open    volumn
# Date
# 2020-10-15  210.615601  211.286775  207.115879  208.161010  22733100
# 2020-10-16  210.615601  213.137302  210.289603  211.085416  26057900
# 2020-10-19  205.399536  213.146846  204.920124  211.344249  27625800
# 2020-10-20  205.811859  208.419865  204.316094  206.914517  22753500
# 2020-10-21  205.955688  207.988394  204.344854  204.344854  22724900
# ...                ...         ...         ...         ...       ...
# 2025-10-08  524.849976  526.950012  523.090027  523.280029  13363400
# 2025-10-09  522.400024  524.330017  517.400024  522.340027  18343600
# 2025-10-10  510.959991  523.580017  509.630005  519.640015  24133800
# 2025-10-13  514.049988  516.409973  511.679993  516.409973  14284200
# 2025-10-14  513.570007  515.280029  506.000000  510.230011  14669900
#
# [1255 rows x 5 columns]

# %%
data.index
# Out:
# DatetimeIndex(['2020-10-15', '2020-10-16', '2020-10-19', '2020-10-20',
#                '2020-10-21', '2020-10-22', '2020-10-23', '2020-10-26',
#                '2020-10-27', '2020-10-28',
#                ...
#                '2025-10-01', '2025-10-02', '2025-10-03', '2025-10-06',
#                '2025-10-07', '2025-10-08', '2025-10-09', '2025-10-10',
#                '2025-10-13', '2025-10-14'],
#               dtype='datetime64[ns]', name='Date', length=1255, freq=None)

# %%
df  =  data[['close']]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#                  close
# Date
# 2020-10-15  210.615601
# 2020-10-16  210.615601
# 2020-10-19  205.399536
# 2020-10-20  205.811859
# 2020-10-21  205.955688
# ...                ...
# 2025-10-08  524.849976
# 2025-10-09  522.400024
# 2025-10-10  510.959991
# 2025-10-13  514.049988
# 2025-10-14  513.570007
#
# [1255 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df)

# %%
df.head()
# Out:
#                  close
# Date
# 2020-10-15  210.615601
# 2020-10-16  210.615601
# 2020-10-19  205.399536
# 2020-10-20  205.811859
# 2020-10-21  205.955688

# %%
df.tail()
# Out:
#                  close
# Date
# 2025-10-08  524.849976
# 2025-10-09  522.400024
# 2025-10-10  510.959991
# 2025-10-13  514.049988
# 2025-10-14  513.570007

# %%
# use  scaling
from  sklearn.preprocessing import MinMaxScaler
mm  =  MinMaxScaler()

# %%
import pandas as pd

# %%
df  = pd.DataFrame(mm.fit_transform(df) ,  columns  =  ['close'] )

# %%
df.index =  data.index

# %%
df
# Out:
#                close
# Date
# 2020-10-15  0.048763
# 2020-10-16  0.048763
# 2020-10-19  0.033456
# 2020-10-20  0.034666
# 2020-10-21  0.035088
# ...              ...
# 2025-10-08  0.970915
# 2025-10-09  0.963726
# 2025-10-10  0.930154
# 2025-10-13  0.939222
# 2025-10-14  0.937813
#
# [1255 rows x 1 columns]

# %%
plt.plot(df)

# %%
def lagged_data(df  ,  lag):
  for  i  in range(lag):
    df[f'lag{i+1}'] =  df['close'].shift(i+1)
  return  df

# %%
df1  =  lagged_data(df  , 60)

# %%
df1.shape
# Out:
# (1255, 61)

# %%
df1.head()
# Out:
#                close      lag1      lag2      lag3      lag4  lag5  lag6  \
# Date
# 2020-10-15  0.048763       NaN       NaN       NaN       NaN   NaN   NaN
# 2020-10-16  0.048763  0.048763       NaN       NaN       NaN   NaN   NaN
# 2020-10-19  0.033456  0.048763  0.048763       NaN       NaN   NaN   NaN
# 2020-10-20  0.034666  0.033456  0.048763  0.048763       NaN   NaN   NaN
# 2020-10-21  0.035088  0.034666  0.033456  0.048763  0.048763   NaN   NaN
#
#             lag7  lag8  lag9  ...  lag51  lag52  lag53  lag54  lag55  lag56  \
# Date                          ...
# 2020-10-15   NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 2020-10-16   NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 2020-10-19   NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 2020-10-20   NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 2020-10-21   NaN   NaN   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
#
#             lag57  lag58  lag59  lag60
# Date
# 2020-10-15    NaN    NaN    NaN    NaN
# 2020-10-16    NaN    NaN    NaN    NaN
# 2020-10-19    NaN    NaN    NaN    NaN
# 2020-10-20    NaN    NaN    NaN    NaN
# 2020-10-21    NaN    NaN    NaN    NaN
#
# [5 rows x 61 columns]

# %%
df1  =  df1.dropna()

# %%
df1
# Out:
#                close      lag1      lag2      lag3      lag4      lag5  \
# Date
# 2021-01-12  0.037037  0.044259  0.050268  0.046516  0.029476  0.045416
# 2021-01-13  0.041015  0.037037  0.044259  0.050268  0.046516  0.029476
# 2021-01-14  0.031648  0.041015  0.037037  0.044259  0.050268  0.046516
# 2021-01-15  0.030605  0.031648  0.041015  0.037037  0.044259  0.050268
# 2021-01-19  0.041297  0.030605  0.031648  0.041015  0.037037  0.044259
# ...              ...       ...       ...       ...       ...       ...
# 2025-10-08  0.970915  0.968362  0.981832  0.948906  0.944181  0.955832
# 2025-10-09  0.963726  0.970915  0.968362  0.981832  0.948906  0.944181
# 2025-10-10  0.930154  0.963726  0.970915  0.968362  0.981832  0.948906
# 2025-10-13  0.939222  0.930154  0.963726  0.970915  0.968362  0.981832
# 2025-10-14  0.937813  0.939222  0.930154  0.963726  0.970915  0.968362
#
#                 lag6      lag7      lag8      lag9  ...     lag51     lag52  \
# Date                                                ...
# 2021-01-12  0.044823  0.058167  0.056080  0.063048  ...  0.000985  0.030726
# 2021-01-13  0.045416  0.044823  0.058167  0.056080  ...  0.006725  0.000985
# 2021-01-14  0.029476  0.045416  0.044823  0.058167  ...  0.000394  0.006725
# 2021-01-15  0.046516  0.029476  0.045416  0.044823  ...  0.000000  0.000394
# 2021-01-19  0.050268  0.046516  0.029476  0.045416  ...  0.011536  0.000000
# ...              ...       ...       ...       ...  ...       ...       ...
# 2025-10-08  0.950667  0.940836  0.931621  0.918621  ...  0.932205  0.935750
# 2025-10-09  0.955832  0.950667  0.940836  0.931621  ...  0.932410  0.932205
# 2025-10-10  0.944181  0.955832  0.950667  0.940836  ...  0.934373  0.932410
# 2025-10-13  0.948906  0.944181  0.955832  0.950667  ...  0.993730  0.934373
# 2025-10-14  0.981832  0.948906  0.944181  0.955832  ...  0.966219  0.993730
#
#                lag53     lag54     lag55     lag56     lag57     lag58  \
# Date
# 2021-01-12  0.021807  0.039111  0.035341  0.035088  0.034666  0.033456
# 2021-01-13  0.030726  0.021807  0.039111  0.035341  0.035088  0.034666
# 2021-01-14  0.000985  0.030726  0.021807  0.039111  0.035341  0.035088
# 2021-01-15  0.006725  0.000985  0.030726  0.021807  0.039111  0.035341
# 2021-01-19  0.000394  0.006725  0.000985  0.030726  0.021807  0.039111
# ...              ...       ...       ...       ...       ...       ...
# 2025-10-08  0.927458  0.912780  0.911022  0.925056  0.925027  0.929861
# 2025-10-09  0.935750  0.927458  0.912780  0.911022  0.925056  0.925027
# 2025-10-10  0.932205  0.935750  0.927458  0.912780  0.911022  0.925056
# 2025-10-13  0.932410  0.932205  0.935750  0.927458  0.912780  0.911022
# 2025-10-14  0.934373  0.932410  0.932205  0.935750  0.927458  0.912780
#
#                lag59     lag60
# Date
# 2021-01-12  0.048763  0.048763
# 2021-01-13  0.033456  0.048763
# 2021-01-14  0.034666  0.033456
# 2021-01-15  0.035088  0.034666
# 2021-01-19  0.035341  0.035088
# ...              ...       ...
# 2025-10-08  0.912048  0.912634
# 2025-10-09  0.929861  0.912048
# 2025-10-10  0.925027  0.929861
# 2025-10-13  0.925056  0.925027
# 2025-10-14  0.911022  0.925056
#
# [1195 rows x 61 columns]

# %%
df1.shape
# Out:
# (1195, 61)

# %%
1255-60
# Out:
# 1195

# %%
x  =  df1.iloc[: ,  1:]
y  =  df1.iloc[: ,  0]

# %%
x.head()
# Out:
#                 lag1      lag2      lag3      lag4      lag5      lag6  \
# Date
# 2021-01-12  0.044259  0.050268  0.046516  0.029476  0.045416  0.044823
# 2021-01-13  0.037037  0.044259  0.050268  0.046516  0.029476  0.045416
# 2021-01-14  0.041015  0.037037  0.044259  0.050268  0.046516  0.029476
# 2021-01-15  0.031648  0.041015  0.037037  0.044259  0.050268  0.046516
# 2021-01-19  0.030605  0.031648  0.041015  0.037037  0.044259  0.050268
#
#                 lag7      lag8      lag9     lag10  ...     lag51     lag52  \
# Date                                                ...
# 2021-01-12  0.058167  0.056080  0.063048  0.065333  ...  0.000985  0.030726
# 2021-01-13  0.044823  0.058167  0.056080  0.063048  ...  0.006725  0.000985
# 2021-01-14  0.045416  0.044823  0.058167  0.056080  ...  0.000394  0.006725
# 2021-01-15  0.029476  0.045416  0.044823  0.058167  ...  0.000000  0.000394
# 2021-01-19  0.046516  0.029476  0.045416  0.044823  ...  0.011536  0.000000
#
#                lag53     lag54     lag55     lag56     lag57     lag58  \
# Date
# 2021-01-12  0.021807  0.039111  0.035341  0.035088  0.034666  0.033456
# 2021-01-13  0.030726  0.021807  0.039111  0.035341  0.035088  0.034666
# 2021-01-14  0.000985  0.030726  0.021807  0.039111  0.035341  0.035088
# 2021-01-15  0.006725  0.000985  0.030726  0.021807  0.039111  0.035341
# 2021-01-19  0.000394  0.006725  0.000985  0.030726  0.021807  0.039111
#
#                lag59     lag60
# Date
# 2021-01-12  0.048763  0.048763
# 2021-01-13  0.033456  0.048763
# 2021-01-14  0.034666  0.033456
# 2021-01-15  0.035088  0.034666
# 2021-01-19  0.035341  0.035088
#
# [5 rows x 60 columns]

# %%
y.head()
# Out:
# Date
# 2021-01-12    0.037037
# 2021-01-13    0.041015
# 2021-01-14    0.031648
# 2021-01-15    0.030605
# 2021-01-19    0.041297
# Name: close, dtype: float64

# %%
y.shape
# Out:
# (1195,)

# %%
x.shape
y.shape
# Out:
# (1195,)

# %%
1195*0.8
# Out:
# 956.0

# %%
from sklearn.model_selection import  train_test_split

# %%
x_train ,  x_test ,  y_train  ,  y_test   =  train_test_split(x  ,  y  , test_size  =  0.2  ,  random_state= 2)

# %%
print(x_train.shape  , y_train.shape)
print(x_test.shape  , y_test.shape)
# Out:
# (956, 60) (956,)
# (239, 60) (239,)

# %% [markdown]
# #### create architechture

# %%
from keras.models  import Sequential
from keras.layers  import LSTM  , Dense   , Dropout

# %%
nn  =  Sequential()

# add lstm layers
nn.add(LSTM(units  = 128  ,   input_shape  =  (x_train.shape[1] , 1) ,  return_sequences  =  True ))

nn.add(LSTM(units  =  256 , return_sequences  =  True   ))
nn.add(Dropout(0.3))

nn.add(LSTM(units  =  256 ,  return_sequences  =  True))
nn.add(Dropout(0.3))

nn.add(Dense(units  =  1 ,  activation  =  'linear'))

# %%
##  model  compilation
nn.compile(optimizer  =  'adam' ,  loss  = 'mse' , metrics  = ['mae'])

# %%
from  keras.callbacks import EarlyStopping
es  =  EarlyStopping(monitor  = 'val_loss' ,  patience= 5)

# %%
##  model  fitting
hist  =  nn.fit(x_train  ,  y_train  , validation_split= 0.2  ,  epochs  =  100 ,  callbacks  =  es )
# Out:
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 0.0890 - mae: 0.2121 - val_loss: 0.0232 - val_mae: 0.1124
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0173 - mae: 0.0886 - val_loss: 0.0151 - val_mae: 0.0810
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0135 - mae: 0.0767 - val_loss: 0.0147 - val_mae: 0.0818
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0126 - mae: 0.0761 - val_loss: 0.0117 - val_mae: 0.0732
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0107 - mae: 0.0717 - val_loss: 0.0119 - val_mae: 0.0767
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0117 - mae: 0.0770 - val_loss: 0.0111 - val_mae: 0.0742
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0117 - mae: 0.0774 - val_loss: 0.0115 - val_mae: 0.0770
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0091 - mae: 0.0682 - val_loss: 0.0097 - val_mae: 0.0705
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0087 - mae: 0.0666 - val_loss: 0.0090 - val_mae: 0.0688
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0085 - mae: 0.0675 - val_loss: 0.0089 - val_mae: 0.0688
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0082 - mae: 0.0655 - val_loss: 0.0082 - val_mae: 0.0661
# Epoch 12/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0083 - mae: 0.0658 - val_loss: 0.0080 - val_mae: 0.0654
# Epoch 13/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0074 - mae: 0.0629 - val_loss: 0.0080 - val_mae: 0.0661
# Epoch 14/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0073 - mae: 0.0629 - val_loss: 0.0077 - val_mae: 0.0653
# Epoch 15/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0077 - mae: 0.0649 - val_loss: 0.0076 - val_mae: 0.0645
# Epoch 16/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0072 - mae: 0.0630 - val_loss: 0.0079 - val_mae: 0.0674
# Epoch 17/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0073 - mae: 0.0633 - val_loss: 0.0070 - val_mae: 0.0626
# Epoch 18/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0068 - mae: 0.0619 - val_loss: 0.0065 - val_mae: 0.0618
# Epoch 19/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0061 - mae: 0.0584 - val_loss: 0.0065 - val_mae: 0.0612
# Epoch 20/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0062 - mae: 0.0599 - val_loss: 0.0067 - val_mae: 0.0643
# Epoch 21/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0062 - mae: 0.0600 - val_loss: 0.0061 - val_mae: 0.0618
# Epoch 22/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0058 - mae: 0.0589 - val_loss: 0.0071 - val_mae: 0.0620
# Epoch 23/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0073 - mae: 0.0642 - val_loss: 0.0069 - val_mae: 0.0644
# Epoch 24/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0065 - mae: 0.0628 - val_loss: 0.0066 - val_mae: 0.0627
# Epoch 25/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0064 - mae: 0.0617 - val_loss: 0.0064 - val_mae: 0.0616
# Epoch 26/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0059 - mae: 0.0587 - val_loss: 0.0087 - val_mae: 0.0719

# %%
nn.evaluate(x_train  ,  y_train)
# Out:
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0079 - mae: 0.0691
# [0.007951002568006516, 0.06914307922124863]

# %%
nn.evaluate(x_test  ,  y_test)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0069 - mae: 0.0651
# [0.007227808237075806, 0.06661046296358109]
